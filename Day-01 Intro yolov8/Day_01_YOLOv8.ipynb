# %%
#!pip install ultralytics

# %% [markdown]
# # Detection

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model
model = YOLO('yolov8n')

# Perform object detection on an image
result = model('football.jpg')
result[0].show()
# Out:
# image 1/1 /content/football.jpg: 448x640 2 persons, 1 sports ball, 9.9ms
# Speed: 1.6ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model
model = YOLO('yolov8n')

# Perform object detection on an image
result = model('/content/he2.mp4', save=True)
# result[0].plot()
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/224) /content/he2.mp4: 384x640 7 persons, 2 cars, 10 motorcycles, 1 truck, 91.3ms
# video 1/1 (frame 2/224) /content/he2.mp4: 384x640 7 persons, 3 cars, 11 motorcycles, 10.0ms
# video 1/1 (frame 3/224) /content/he2.mp4: 384x640 6 persons, 1 car, 13 motorcycles, 8.7ms
# video 1/1 (frame 4/224) /content/he2.mp4: 384x640 8 persons, 1 car, 11 motorcycles, 9.5ms
# ...

# %% [markdown]
# # segmentation

# %%
from ultralytics import YOLO

# Load a pre-trained YOLO model
model = YOLO('yolov8n-seg.pt')

# Perform object detection on an image
result = model('football.jpg')
result[0].show()
# Out:
# ...
# 100%|██████████| 6.74M/6.74M [00:00<00:00, 117MB/s]
# image 1/1 /content/football.jpg: 448x640 2 persons, 1 sports ball, 19.3ms
# Speed: 2.0ms preprocess, 19.3ms inference, 15.3ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=275x183>

# %% [markdown]
# # Pose Estimation

# %%
from ultralytics import YOLO

# mode train
model = YOLO('yolov8n-pose.pt')
# model.train(data='coco128.yaml', epochs=3)

# Perform object detection on an image
results = model("football.jpg", save=True)
results[0].show()
# Out:
# ...
# 100%|██████████| 6.52M/6.52M [00:00<00:00, 104MB/s]
# image 1/1 /content/football.jpg: 448x640 2 persons, 19.7ms
# Speed: 1.6ms preprocess, 19.7ms inference, 35.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/pose/predict
# <PIL.Image.Image image mode=RGB size=275x183>

# %% [markdown]
# # Image Classification

# %%
from ultralytics import YOLO

# Load model
model = YOLO('yolov8n-cls.pt')

# Perform classification on an image
results = model('football.jpg')
results[0].show()
# Out:
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 82.4MB/s]
# image 1/1 /content/football.jpg: 224x224 soccer_ball 1.00, croquet_ball 0.00, golf_ball 0.00, baseball 0.00, rugby_ball 0.00, 2.7ms
# Speed: 46.9ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 23.7MB/s]
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
from ultralytics import YOLO

# Load model
model = YOLO('yolov8n-obb.pt')

# Perform obb on an image
results = model('/content/he2.mp4', save=True)
#results[0].plot()
# Out:
# ...
# 100%|██████████| 6.26M/6.26M [00:00<00:00, 120MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/224) /content/he2.mp4: 576x1024 43.8ms
# video 1/1 (frame 2/224) /content/he2.mp4: 576x1024 11.6ms
# video 1/1 (frame 3/224) /content/he2.mp4: 576x1024 10.0ms
# video 1/1 (frame 4/224) /content/he2.mp4: 576x1024 10.6ms
# video 1/1 (frame 5/224) /content/he2.mp4: 576x1024 10.3ms
# video 1/1 (frame 6/224) /content/he2.mp4: 576x1024 10.5ms
# ...
