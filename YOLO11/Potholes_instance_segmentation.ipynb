# %% [markdown]
# Database link: https://universe.roboflow.com/potholedetection-ceiz9/pothole-detection-project-1dpiq

# %% [markdown]
# # Step 1: Install Dependencies

# %%
# !nvidia-smi
# Out:
# Sat May 24 15:23:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 41.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 142.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 39.5 MB/s eta 0:00:00
# ...

# %%
from roboflow import Roboflow
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Nt0ukj1io3hVphvI14o3")
project = rf.workspace("potholedetection-ceiz9").project("pothole-detection-project-1dpiq")
version = project.version(11)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pothole-Detection-Project-11 in yolov11:: 100%|██████████| 8536/8536 [00:01<00:00, 6474.92it/s]

# %% [markdown]
# # Train YOLOv11 Model

# %%
# Load a model
model = YOLO("yolo11n-seg.pt")

# Train the model
train_results = model.train(
    data="/content/Pothole-Detection-Project-11/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device=0,
)
# Out:
# ...
# 100%|██████████| 5.90M/5.90M [00:00<00:00, 119MB/s]
# Ultralytics 8.3.143 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# # Inference

# %%
from IPython.display import Image

# %%
Image("/content/runs/segment/train/results.png", width=600)

# %%
Image("/content/runs/segment/train/confusion_matrix.png", width=600)

# %%
Image("/content/runs/segment/train/train_batch0.jpg", width=600)

# %%
Image("/content/runs/segment/train/train_batch1.jpg", width=600)

# %%
Image("/content/runs/segment/train/train_batch2.jpg", width=600)

# %%
model = YOLO('/content/runs/segment/train/weights/best.pt')
results = model("/content/download.jpg", save=True)
results[0].show()
# Out:
# image 1/1 /content/download.jpg: 480x640 10 Potholes, 88.5ms
# Speed: 2.3ms preprocess, 88.5ms inference, 11.4ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/segment/predict
# <PIL.Image.Image image mode=RGB size=204x148>
