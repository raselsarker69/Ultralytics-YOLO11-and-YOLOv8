# %% [markdown]
# # YOLO11 Image Classification on Custom Dataset

# %% [markdown]
# Database: https://universe.roboflow.com/cheetah-qcrng/retinal-disease-classification-rxn62

# %% [markdown]
# ## Step 1: Install Dependencies

# %%
# !nvidia-smi
# Out:
# Fri May 30 10:10:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla P100-PCIE-16GB           Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0             25W /  250W |       0MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.4 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 5.4 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.9.41
#     Uninstalling nvidia-nvjitlink-cu12-12.9.41:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.9.41
# ...

# %% [markdown]
# ## Step 02 # Import All the Requried Libraries

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.146 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6362.0/8062.4 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %% [markdown]
# ## Step # 04 Train YOLO11 Model on a Custom Dataset

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='/kaggle/input/retinal-disease-classification', epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.146 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %% [markdown]
# ## Step # 05 Examine Training Results

# %%
Image("/kaggle/working/runs/classify/train2/results.png", width=600)

# %%
Image("/kaggle/working/runs/classify/train2/confusion_matrix.png", width=600)

# %%
Image("/kaggle/working/runs/classify/train2/train_batch0.jpg", width=600)

# %%
Image("/kaggle/working/runs/classify/train2/train_batch1.jpg", width=600)

# %%
Image("/kaggle/working/runs/classify/train2/train_batch2.jpg", width=600)

# %% [markdown]
# ## Step # 06 Inference

# %%
model = YOLO('/kaggle/working/runs/classify/train2/weights/best.pt')
results = model("/kaggle/input/retinal-disease-classification/test/3_retina_disease/0004_png.rf.fea138c41057f08d108089b7f0f75c0b.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-classification/test/3_retina_disease/0004_png.rf.fea138c41057f08d108089b7f0f75c0b.jpg: 640x640 3_retina_disease 1.00, 1_normal 0.00, 2_cataract 0.00, 2_glaucoma 0.00, 5.1ms
# Speed: 10.6ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict2
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
Image("/kaggle/working/runs/classjpg", width=600)

# %%
results = model("/kaggle/input/retinal-disease-classification/test/2_glaucoma/0002_png.rf.e6d462bb73306e2d320bbfb4dc1ab1ad.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-classification/test/2_glaucoma/0002_png.rf.e6d462bb73306e2d320bbfb4dc1ab1ad.jpg: 640x640 2_glaucoma 1.00, 2_cataract 0.00, 1_normal 0.00, 3_retina_disease 0.00, 5.3ms
# Speed: 9.7ms preprocess, 5.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict2
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results = model("/kaggle/input/retinal-disease-classification/test/2_cataract/0005_png.rf.f5d0a272023ba23f8ac4a60b9ba19f1e.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-classification/test/2_cataract/0005_png.rf.f5d0a272023ba23f8ac4a60b9ba19f1e.jpg: 640x640 2_cataract 1.00, 2_glaucoma 0.00, 1_normal 0.00, 3_retina_disease 0.00, 5.2ms
# Speed: 11.5ms preprocess, 5.2ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict2
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results = model("/kaggle/input/retinal-disease-classification/test/1_normal/0012_png.rf.f68fc3c43935229178ee297129bcb928.jpg", conf=0.5, save=True)
results[0].show()
# Out:
# image 1/1 /kaggle/input/retinal-disease-classification/test/1_normal/0012_png.rf.f68fc3c43935229178ee297129bcb928.jpg: 640x640 2_glaucoma 0.84, 1_normal 0.16, 3_retina_disease 0.00, 2_cataract 0.00, 5.6ms
# Speed: 11.8ms preprocess, 5.6ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict2
# <PIL.Image.Image image mode=RGB size=224x224>
